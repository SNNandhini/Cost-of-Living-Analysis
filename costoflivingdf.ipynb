# %%
#Import dependencies

import os
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create FilePath for CSV file

csv_path = "Data/Cost_of_living_indices_data.csv"
df = pd.read_csv(csv_path)

# Output
df
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Afghanistan                 20.37        2.72
# 1       2      Albania                 35.50        8.47
# 2       3      Algeria                 26.87        4.59
# 3       4    Argentina                 34.69        7.71
# 4       5      Armenia                 33.89       11.61
# ..    ...          ...                   ...         ...
# 134   135    Venezuela                 43.20        9.99
# 135   136      Vietnam                 37.48       13.22
# 136   137        Yemen                 53.14        6.71
# 137   138       Zambia                 33.04        9.26
# 138   139     Zimbabwe                 45.68        8.75
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             12.09            14.92                   12.41
# 1                             22.83            29.32                   25.82
# ...

# %%
# Create data for top 10 performing countries based on Cost of Living Index

Df_1 = df.sort_values(["Cost of Living Index"], ascending=False)


# Top 10 Countries DataFrame Output

top_10_countries_df = Df_1.head(10)

# Output
top_10_countries_df
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 15     16      Bermuda                146.04       98.58
# 119   120  Switzerland                123.35       53.54
# 90     91       Norway                100.90       34.68
# 51     52      Iceland                 94.86       41.93
# 11     12     Barbados                 92.37       21.99
# 62     63       Jersey                 92.02       65.33
# 57     58       Israel                 88.05       33.94
# 32     33      Denmark                 84.12       33.23
# 8       9      Bahamas                 84.00       35.34
# 109   110    Singapore                 83.98       66.43
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 15                           123.80           148.66                  159.17
# 119                           90.62           128.13                  122.09
# 90                            69.86            97.31                  105.49
# ...

# %%
# Save Top 10 Countries as CSV file
top_10_countries_df.to_csv("Top_10_Countries.csv", index=False)

# %%
# Bottom 10 countries Output

Bottom_10_Countries_df = Df_1.tail(10)

Bottom_10_Countries_df
# Out:
#      Rank                      Country  Cost of Living Index  Rent Index  \
# 126   127                       Turkey                 28.31        6.63
# 84     85                        Nepal                 28.29        3.96
# 125   126                      Tunisia                 27.87        5.32
# 133   134                   Uzbekistan                 27.31        9.29
# 66     67  Kosovo (Disputed Territory)                 27.05        8.04
# 2       3                      Algeria                 26.87        4.59
# 26     27                     Colombia                 26.72        8.18
# 52     53                        India                 24.43        5.30
# 0       1                  Afghanistan                 20.37        2.72
# 92     93                     Pakistan                 19.92        3.91
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 126                           18.15            22.64                   18.40
# ...

# %%
# Save Bottom 10 countries as CSV 
Bottom_10_Countries_df.to_csv("Bottom_10_Countries.csv", index=False)

# %%
# Show all columns in data

top_10_countries_df.columns
# Out:
# Index(['Rank', 'Country', 'Cost of Living Index', 'Rent Index',
#        'Cost of Living Plus Rent Index', 'Groceries Index',
#        'Restaurant Price Index', 'Local Purchasing Power Index'],
#       dtype='object')

# %%
# Pick the columns to be used

list_of_columns = ["Country", "Cost of Living Index"]

#Output new Data Frame
new_df = Df_1[list_of_columns]
new_df
# Out:
#          Country  Cost of Living Index
# 15       Bermuda                146.04
# 119  Switzerland                123.35
# 90        Norway                100.90
# 51       Iceland                 94.86
# 11      Barbados                 92.37
# ..           ...                   ...
# 2        Algeria                 26.87
# 26      Colombia                 26.72
# 52         India                 24.43
# 0    Afghanistan                 20.37
# 92      Pakistan                 19.92
#
# [139 rows x 2 columns]

# %%
# Top 10 Performing Countries based on Cost of Living Index
 
new_df.head(10)
# Out:
#          Country  Cost of Living Index
# 15       Bermuda                146.04
# 119  Switzerland                123.35
# 90        Norway                100.90
# 51       Iceland                 94.86
# 11      Barbados                 92.37
# 62        Jersey                 92.02
# 57        Israel                 88.05
# 32       Denmark                 84.12
# 8        Bahamas                 84.00
# 109    Singapore                 83.98

# %%
#Bottom 10 Perfoming Countries based on Cost of Living Index

new_df.tail(10)
# Out:
#                          Country  Cost of Living Index
# 126                       Turkey                 28.31
# 84                         Nepal                 28.29
# 125                      Tunisia                 27.87
# 133                   Uzbekistan                 27.31
# 66   Kosovo (Disputed Territory)                 27.05
# 2                        Algeria                 26.87
# 26                      Colombia                 26.72
# 52                         India                 24.43
# 0                    Afghanistan                 20.37
# 92                      Pakistan                 19.92

# %%
# Save Bottom 10 Countries as CSV

# %%
Df_1
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 15     16      Bermuda                146.04       98.58
# 119   120  Switzerland                123.35       53.54
# 90     91       Norway                100.90       34.68
# 51     52      Iceland                 94.86       41.93
# 11     12     Barbados                 92.37       21.99
# ..    ...          ...                   ...         ...
# 2       3      Algeria                 26.87        4.59
# 26     27     Colombia                 26.72        8.18
# 52     53        India                 24.43        5.30
# 0       1  Afghanistan                 20.37        2.72
# 92     93     Pakistan                 19.92        3.91
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 15                           123.80           148.66                  159.17
# 119                           90.62           128.13                  122.09
# ...

# %%
G8_countries = ["Japan", "United States", "United Kingdom", "Canada", "Germany", "Italy", "France", "Russia"]


Df_1["Country"].unique()
# Out:
# array(['Bermuda', 'Switzerland', 'Norway', 'Iceland', 'Barbados',
#        'Jersey', 'Israel', 'Denmark', 'Bahamas', 'Singapore', 'Guernsey',
#        'Hong Kong', 'Luxembourg', 'Australia', 'Japan', 'Ireland',
#        'Netherlands', 'New Zealand', 'France', 'South Korea', 'Finland',
#        'Belgium', 'Sweden', 'Austria', 'Canada', 'United States',
#        'United Kingdom', 'Lebanon', 'Malta', 'Macao', 'Puerto Rico',
#        'Italy', 'Seychelles', 'Germany', 'Qatar', 'Taiwan', 'Cyprus',
#        'United Arab Emirates', 'Palestine', 'Maldives', 'Greece', 'Cuba',
#        'Trinidad And Tobago', 'Bahrain', 'Slovenia', 'Spain', 'Estonia',
#        'Yemen', 'Uruguay', 'Suriname', 'Panama', 'Belize', 'Saudi Arabia',
#        'Senegal', 'Jamaica', 'Oman', 'Jordan', 'Cambodia', 'Croatia',
#        'Kuwait', 'Latvia', 'Libya', 'Czech Republic', 'Portugal',
#        'Ethiopia', 'Ivory Coast', 'Costa Rica', 'Zimbabwe', 'Lithuania',
# ...

# %%
# Create DataFrame for G8 Countries

G8_countries = ["Japan", "United States", "United Kingdom", "Canada", "Germany", "Italy", "France", "Russia"]

df_g8 = df[df["Country"].isin(G8_countries)]
df_g8
# Out:
#      Rank         Country  Cost of Living Index  Rent Index  \
# 23     24          Canada                 70.22       34.33
# 41     42          France                 74.13       25.33
# 43     44         Germany                 65.58       27.62
# 58     59           Italy                 66.47       20.55
# 61     62           Japan                 77.03       25.86
# 103   104          Russia                 35.26       13.09
# 130   131  United Kingdom                 69.65       31.84
# 131   132   United States                 70.13       42.07
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 23                            53.40            70.01                   67.86
# 41                            51.26            73.64                   71.84
# 43                            47.78            52.31                   60.91
# 58                            44.95            57.95                   70.58
# ...

# %%
# Save Data Frame as a csv file 
df_g8.to_csv("G-8_Countries_cost_of_living.csv", index=False)

# %%
# Save Data Frame as an excel file 

df_g8.to_excel("G-8_Countries_cost_of_living.xlsx", index=False)

# %% [markdown]
# # Bar Charts

# %%
# Generate a bar plot showing the Cost of Living Index for the G8 Countries
plot = df_g8.plot.bar(figsize=(9,6), x="Country", y="Cost of Living Index")  
# Set the xlabel and ylabel using class methods
plt.title("G8 Cost of Living Index")
plt.xlabel("Country")
plt.ylabel("Cost of Living Index")
plt.show()

# %%
plot = df_g8.plot.bar(figsize=(9,6), x="Country", y="Rent Index")  
plt.title("G8 Rent Index")
plt.xlabel("Country")
plt.ylabel("Rent Index")
plt.show()

# %%
plot = df_g8.plot.bar(figsize=(9,6), x="Country", y="Groceries Index")  
plt.title("G8 Groceries Index")
plt.xlabel("Country")
plt.ylabel("Groceries Index")
plt.show()

# %%
plot = df_g8.plot.bar(figsize=(9,6), x="Country", y="Restaurant Price Index")  
plt.title("G8 Restaurant Price Index")
plt.xlabel("Country")
plt.ylabel("Restaurant Price Index")
plt.show()

# %%
plot = df_g8.plot.bar(figsize=(9,6), x="Country", y="Local Purchasing Power Index")  
plt.title("G8 Local Purchasing Power Index")
plt.xlabel("Country")
plt.ylabel("Local Purchasing Power Index")
plt.show()

# %% [markdown]
# # Pie Charts

# %%
countries = df_g8["Country"]
cost_of_living = df_g8["Cost of Living Index"]
colors = ["yellow", "green", "lightblue", "orange", "pink", "purple", "red", "lightcoral"]
explode = (0, 0, 0, 0, 0, 0, 0.1, 0)

# %%
plt.pie(cost_of_living, explode = explode, labels=countries, colors=colors, shadow=True, autopct="%1.1f%%")
plt.axis="equal"
plt.title("G8 Cost of Living Index")
# Out:
# Text(0.5, 1.0, 'G8 Cost of Living Index')

# %%
rent_index = df_g8["Rent Index"]
plt.pie(rent_index, explode = explode, labels=countries, colors=colors, shadow=True, autopct="%1.1f%%")
plt.axis="equal"
plt.title("G8 Rent Index")
# Out:
# Text(0.5, 1.0, 'G8 Rent Index')

# %%
groceries_index = df_g8["Groceries Index"]
plt.pie(groceries_index, explode = explode, labels=countries, colors=colors, shadow=True, autopct="%1.1f%%")
plt.axis="equal"
plt.title("G8 Groceries Index")
# Out:
# Text(0.5, 1.0, 'G8 Groceries Index')

# %%
restaurant_price_index = df_g8["Restaurant Price Index"]
plt.pie(restaurant_price_index, explode = explode, labels=countries, colors=colors, shadow=True, autopct="%1.1f%%")
plt.axis="equal"
plt.title("G8 Restaurant Price Index")
# Out:
# Text(0.5, 1.0, 'G8 Restaurant Price Index')

# %%
lpp_index = df_g8["Local Purchasing Power Index"]
plt.pie(lpp_index, explode = explode, labels=countries, colors=colors, shadow=True, autopct="%1.1f%%")
plt.axis="equal"
plt.title("G8 Local Purchasing Power Index")
# Out:
# Text(0.5, 1.0, 'G8 Local Purchasing Power Index')
